# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import datetime

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
start = '2015-01-01'
end = datetime.datetime.now()
print(f"Start date: {start}")
print(f"End date: {end}")
# Out:
# Start date: 2015-01-01
# End date: 2026-04-03 11:58:14.773875

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
stocks = ['AAPL', 'TSLA', 'TWTR', 'IBM', 'LNKD']

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
df = yf.download(stocks, start=start, end=end)
print(df.head())
# Out:
# [**********************60%****                   ]  3 of 5 completed$LNKD: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-04-03 11:58:14.773875)
# [**********************80%*************          ]  4 of 5 completed$TWTR: possibly delisted; no timezone found
# [*********************100%***********************]  5 of 5 completed
#
# 2 Failed downloads:
# ['LNKD']: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-04-03 11:58:14.773875)
# ['TWTR']: possibly delisted; no timezone found
# Price      Adj Close           Close                                  \
# Ticker          LNKD TWTR       AAPL        IBM LNKD       TSLA TWTR
# Date
# 2015-01-02       NaN  NaN  24.214893  97.566772  NaN  14.620667  NaN
# 2015-01-05       NaN  NaN  23.532719  96.031578  NaN  14.006000  NaN
# 2015-01-06       NaN  NaN  23.534935  93.960556  NaN  14.085333  NaN
# 2015-01-07       NaN  NaN  23.864950  93.346489  NaN  14.063333  NaN
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x000001D656BA6A40>

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = df['Volume']

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol_weekly = vol.resample('W').sum()

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
vol_2015 = vol.loc['2015']
vol_2015_total = vol_2015.sum().sum()
print(f"Total volume traded in 2015: {vol_2015_total}")
# Out:
# Total volume traded in 2015: 69743906000.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Bonus: What is the average closing price for each stock by year?
closing_prices = df['Close']
yearly_avg = closing_prices.resample('YE').mean()
print("Average Closing Price by Year:")
print(yearly_avg)
# Out:
# Average Closing Price by Year:
# Ticker            AAPL         IBM  LNKD        TSLA  TWTR
# Date
# 2015-12-31   26.819587   95.002411   NaN   15.336193   NaN
# 2016-12-31   23.855402   95.572313   NaN   13.984484   NaN
# 2017-12-31   34.981397  103.651298   NaN   20.954420   NaN
# 2018-12-31   44.597008   98.489102   NaN   21.153995   NaN
# 2019-12-31   49.902125   98.397468   NaN   18.235347   NaN
# 2020-12-31   92.434114   93.681101   NaN   96.665689   NaN
# 2021-12-31  137.594373  107.009653   NaN  259.998162   NaN
# 2022-12-31  151.945314  116.422120   NaN  263.093081   NaN
# 2023-12-31  170.351417  127.352394   NaN  217.475240   NaN
# 2024-12-31  205.646686  185.104153   NaN  230.614961   NaN
# 2025-12-31  231.563039  261.844765   NaN  356.970760   NaN
# 2026-12-31  260.012254  269.085921   NaN  410.651110   NaN
