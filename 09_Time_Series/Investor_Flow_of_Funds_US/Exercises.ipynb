# %% [markdown]
# # Investor - Flow of Funds - US

# %% [markdown]
# ### Introduction:
#
# Special thanks to: https://github.com/rgrp for sharing the dataset.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called

# %%
url = 'https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv'
flow = pd.read_csv(url)
flow.head()
# Out:
#          Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0  2022-07-06         10167              NaN          3058     NaN
# 1  2022-07-13          7409              NaN          2808     NaN
# 2  2022-07-20          3468              NaN           102     NaN
# 3  2022-07-27         14213              NaN          9667     NaN
# 4  2022-08-03          9786              NaN          4016     NaN
#
#    Total Bond  Taxable Bond  Municipal Bond  Total
# 0         842           NaN            2216    NaN
# 1        2067           NaN             741    NaN
# 2        -417           NaN             519    NaN
# 3        8598           NaN            1069    NaN
# 4        3079           NaN             937    NaN

# %% [markdown]
# ### Step 4.  What is the frequency of the dataset?

# %%
flow.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             118 non-null    str
#  1   Total Equity     118 non-null    int64
#  2   Domestic Equity  0 non-null      float64
#  3   World Equity     118 non-null    int64
#  4   Hybrid           0 non-null      float64
#  5   Total Bond       118 non-null    int64
#  6   Taxable Bond     0 non-null      float64
#  7   Municipal Bond   118 non-null    int64
#  8   Total            0 non-null      float64
# dtypes: float64(4), int64(4), str(1)
# memory usage: 8.4 KB

# %% [markdown]
# ### Step 5. Set the column Date as the index.

# %%
flow.set_index('Date', inplace=True)

# %% [markdown]
# ### Step 6. What is the type of the index?

# %%
type(flow.index)
# Out:
# pandas.Index

# %% [markdown]
# ### Step 7. Set the index to a DatetimeIndex type

# %%
flow.index = pd.to_datetime(flow.index)
type(flow.index)
# Out:
# pandas.DatetimeIndex

# %% [markdown]
# ### Step 8.  Change the frequency to monthly, sum the values and assign it to monthly.

# %%
monthly = flow.resample('ME').sum()

# %% [markdown]
# ### Step 9. You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.

# %%
monthly = monthly.dropna()

# %% [markdown]
# ### Step 10. Good, now we have the monthly data. Now change the frequency to year.

# %%
yearly = monthly.resample('YE').sum()
yearly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2022-12-31        303689              0.0        197389     0.0      159480
# 2023-12-31        577223              0.0        384006     0.0      301790
# 2024-12-31        501341              0.0        362632     0.0      312430
# 2025-12-31        204465              0.0        126778     0.0       90915
# 2026-12-31        296299              0.0        177177     0.0       85818
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2022-12-31           0.0           37908    0.0
# 2023-12-31           0.0           82214    0.0
# 2024-12-31           0.0           50200    0.0
# 2025-12-31           0.0           35862    0.0
# 2026-12-31           0.0           91358    0.0

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Bonus: What is the average monthly inflow?
avg_monthly = monthly.mean()
print("Average Monthly Inflow by Institution:")
print(avg_monthly)
# Out:
# Average Monthly Inflow by Institution:
# Total Equity       41844.822222
# Domestic Equity        0.000000
# World Equity       27732.933333
# Hybrid                 0.000000
# Total Bond         21120.733333
# Taxable Bond           0.000000
# Municipal Bond      6612.044444
# Total                  0.000000
# dtype: float64
